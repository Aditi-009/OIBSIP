# %% [markdown]
# # Task 1 : Iris Flower Classification

# %% [markdown]
# # Name of Intern :ADITI PALDHARE

# %% [markdown]
# ![iris.png](attachment:iris.png)

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data.shape
# Out:
# (150, 6)

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis - EDA

# %%
#Sepal length distribution
plt.figure(figsize=(6,6))
sns.distplot(data["SepalLengthCm"],color="red")
plt.show()
# Out:
# C:\Users\paldh\AppData\Local\Temp\ipykernel_18680\1874111263.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["SepalLengthCm"],color="red")

# %%
#sepal width distribution
plt.figure(figsize=(6,6))
sns.distplot(data['SepalWidthCm'],color="red")
plt.show()
# Out:
# C:\Users\paldh\AppData\Local\Temp\ipykernel_18680\3877414674.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SepalWidthCm'],color="red")

# %%
#petal length distribution
plt.figure(figsize=(6,6))
sns.distplot(data['PetalLengthCm'],color="red")
plt.show()
# Out:
# C:\Users\paldh\AppData\Local\Temp\ipykernel_18680\1876140145.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['PetalLengthCm'],color="red")

# %%
#petal width distribution
plt.figure(figsize=(6,6))
sns.distplot(data['PetalWidthCm'],color="red")
plt.show()
# Out:
# C:\Users\paldh\AppData\Local\Temp\ipykernel_18680\569399675.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['PetalWidthCm'],color="red")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,6))
sns.countplot(x='Species', data=data, palette="rainbow")
plt.show()

# %%
#Pairplot
sns.pairplot(data,hue='Species')
plt.show()
# Out:
# c:\Users\paldh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Select only the numeric columns from the DataFrame
numeric_data = data.select_dtypes(include=['number'])

# Create the correlation matrix and plot the heatmap
sns.heatmap(numeric_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
#Split & define feature and target
x = data.drop(columns=['Species'])
y=data['Species']

# %%
print(x)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
print(y)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
x.shape,y.shape
# Out:
# ((150, 5), (150,))

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,x_test.shape
# Out:
# ((120, 5), (30, 5))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Logistic regression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# c:\Users\paldh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_y_pred = lr.predict(x_test)
lr_y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %%
lr_results = confusion_matrix(y_test,lr_y_pred)
print("confusion matrix: ")
print(lr_results)
print(accuracy_score(y_test, y_pred))
# Out:
# confusion matrix:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  0  9]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\paldh\OneDrive\Desktop\Iris Flower\Iris Flower Classification.ipynb Cell 31 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/paldh/OneDrive/Desktop/Iris%20Flower/Iris%20Flower%20Classification.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> print("confusion matrix: ")
#       <a href='vscode-notebook-cell:/c%3A/Users/paldh/OneDrive/Desktop/Iris%20Flower/Iris%20Flower%20Classification.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> print(lr_results)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paldh/OneDrive/Desktop/Iris%20Flower/Iris%20Flower%20Classification.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> print(accuracy_score(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# # Decision tree

# %%
DT=DecisionTreeClassifier()
DT.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DT_y_pred = DT.predict(x_test)
DT_y_pred
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor'], dtype=object)

# %%
DT_results = confusion_matrix(y_test,DT_y_pred)
print("confusion matrix: ")
print(DT_results)
print(accuracy_score(y_test,DT_y_pred))
# Out:
# confusion matrix:
# [[ 6  0  0]
#  [ 0 12  0]
#  [ 0  0 12]]
# 1.0
